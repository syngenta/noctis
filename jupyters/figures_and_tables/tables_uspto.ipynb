# %%
import json
import os
from linchemin.cheminfo.constructors import MoleculeConstructor
from linchemin.cgu.translate import translator
from tqdm import tqdm
from noctis.repository.neo4j.neo4j_repository import Neo4jRepository
import time
from concurrent.futures import ThreadPoolExecutor, TimeoutError, as_completed
import itertools
from linchemin.rem.route_descriptors import descriptor_calculator
from linchemin.cgu.syngraph_operations import extract_reactions_from_syngraph
from pandas import DataFrame

# %% [markdown]
# ### Execution of custom queries [Table 3]

# %%
repo = Neo4jRepository( database='uspto')

# %%
### Uncomment if you want to reload the USPTO dataset

# IMPORT_PATH = r'C:\Users\s1222744\Neo4jDesktopDB\relate-data\dbmss\dbms-3b486baa-cae1-4147-8a3d-d7fd445cdede\import'
# If your Neo4j is set up to have an import directory,
# first move the files to the import directory before running this query
# If your Neo4j is set up to import files from anywhere in your file system, define the import path

# repo.execute_custom_query_from_yaml(yaml_file = "./queries/table3.yaml", query_name = 'delete_all_nodes')
# repo.execute_query(query_name = 'import_db_from_csv', folder_path = IMPORT_PATH, prefix = 'USPTO')
# Out:
# 2025-04-07 16:56:38,090 - noctis.repository.neo4j.neo4j_repository - WARNING - Nodes and/or relationships are not defined in the GDB schema DataFrame.
# [<Record file='progress.csv' source='file' format='csv' nodes=1080847 relationships=1336500 properties=3951533 time=86995 rows=0 batchSize=-1 batches=0 done=True data=None>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:521443' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:32433' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:465556' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:32433' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:25' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:835574' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:248402' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:26' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:454726' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:248402' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:35' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:494140' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:257840' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:36' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:454740' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:257840' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:37' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:636018' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:152107' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:38' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451015' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:199140' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:39' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:681178' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:199140' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:41' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451371' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:18573' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:42' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:457032' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:18573' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:53' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:585608' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:141083' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:54' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:699074' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:141083' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:57' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:457125' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:229395' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:58' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451314' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:229395' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:99' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:539360' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262574' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:100' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:460699' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262574' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:102' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:490351' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:78091' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:103' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:601148' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:78091' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:148' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:632991' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:97824' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:149' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:550856' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:199862' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:150' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:782364' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:199862' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:181' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:864657' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262618' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:182' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451022' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262618' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:225' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:462915' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:176085' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:226' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:454685' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:176085' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:271' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452279' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262665' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:272' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:503903' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262665' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:287' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451563' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:139715' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:288' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:461017' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:139715' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:304' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:456379' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:79010' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:305' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452087' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:79010' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:338' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:525939' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:198651' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:339' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:466691' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:198651' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:345' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:864763' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262704' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:346' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:864764' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262704' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:354' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:460829' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:245562' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:355' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:483945' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:245562' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:373' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:507945' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:42694' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:374' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:457179' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:42694' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:421' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:864814' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262745' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:422' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:864815' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262745' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:430' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:864825' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262750' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:433' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:471998' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262752' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:434' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452736' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262752' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:444' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:573147' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:61332' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:466' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:450931' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262770' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:467' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:534005' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262770' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:482' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:651127' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:109394' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:483' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:461296' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:109394' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:516' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451549' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:19719' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:554' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:453656' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:102211' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:555' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:639910' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:102211' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:558' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:484745' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262819' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:559' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:852983' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262819' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:560' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451203' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:34903' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:561' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:496506' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:34903' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:573' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:668978' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:120970' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:602' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:510643' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:40114' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:608' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:635705' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:99551' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:609' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452736' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:99551' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:615' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:450901' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:96658' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:616' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:479515' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:96658' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:622' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:527522' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262850' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:623' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451122' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262850' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:626' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:779248' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262852' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:627' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:456422' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262852' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:647' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:634540' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262864' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:648' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:539999' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262864' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:657' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:744544' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:172493' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:658' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451163' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:172493' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:680' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:773742' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:193568' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:681' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:459863' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:193568' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:688' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:564258' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:192982' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:689' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452993' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:192982' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:690' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:469462' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262886' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:691' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451719' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262886' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:710' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:465111' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262897' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:711' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452279' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262897' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:712' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:594036' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:73808' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:713' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:508806' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:73808' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:719' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:460967' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262902' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:720' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:493217' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262902' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:739' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:460990' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:84223' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:740' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:495177' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:84223' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:745' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:624248' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:234357' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:746' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:454740' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:234357' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:764' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:453133' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:196234' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:765' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:617204' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:196234' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:788' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:535421' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:70074' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:789' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:587867' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:70074' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:804' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:505698' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:23741' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:813' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:651064' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:109350' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:814' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:453211' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:109350' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:837' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:466287' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:113016' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:856' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452531' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:190155' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:857' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:453133' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:190155' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:860' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:513078' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262972' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:867' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451015' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262977' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:868' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:757024' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262977' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:895' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:560352' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:262992' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:909' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:453042' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263000' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:910' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:509597' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263000' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:913' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451424' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263002' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:914' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:506818' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263002' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:927' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:550312' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:48158' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:952' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452747' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263024' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:953' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:500900' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263024' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:957' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452989' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:81525' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:958' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451292' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:81525' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:967' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:743741' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:171937' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:968' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:450905' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:171937' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:969' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:454072' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:779' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:973' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:495033' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:132609' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:985' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:641861' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:164138' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1028' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:455145' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:173021' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1029' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:559474' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:173021' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1030' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:479581' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:83690' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1050' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:865242' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263073' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1053' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:456783' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:111677' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1054' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:453195' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:111677' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1058' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:460685' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:37357' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1059' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:531011' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:37357' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1066' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:560279' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:242506' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1067' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451122' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:242506' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1075' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:600779' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:77860' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1101' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:461508' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263097' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1102' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:454941' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263097' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1103' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:865271' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263098' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1104' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452031' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263098' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1118' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:453125' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:252130' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1119' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:851244' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:252130' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1142' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:607948' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:82235' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1143' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:607949' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:82235' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1171' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:457263' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:16039' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1172' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452686' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:16039' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:1190' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:450901' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:263147' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
# ...
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9894' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:533496' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:257328' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9895' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:634540' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:257328' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9903' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451429' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267756' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9904' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:871089' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267756' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9923' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:871102' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267765' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9926' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451203' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:23333' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9927' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:504918' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:23333' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9957' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:871124' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267783' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9972' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:481650' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:11526' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9973' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452279' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:11526' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9974' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451292' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:11526' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9981' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:467867' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:4908' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:9984' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:871142' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267797' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10014' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:456514' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:165917' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10015' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:548492' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:165917' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10024' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:528647' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:36058' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10032' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:454328' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267822' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10033' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:844566' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267822' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10050' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:871180' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267831' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10051' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451122' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267831' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10095' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:465866' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:64624' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10096' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:475678' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:64624' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10099' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:634208' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:98607' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10100' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451414' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:98607' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10101' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:487683' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:159595' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10104' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:511431' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:83792' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10105' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:465556' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:83792' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10106' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:871215' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267860' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10139' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452838' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267879' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10140' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:493254' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267879' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10161' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:455091' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267891' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10162' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:855723' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267891' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10168' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:871258' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267895' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10169' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:454937' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267895' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10217' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:453794' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:56234' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10218' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:455921' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:56234' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10221' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451923' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:249154' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10222' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:453602' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:249154' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10223' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:550449' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:48229' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10224' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:469356' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:48229' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10229' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:458870' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:136729' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10230' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:452131' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:136729' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10282' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:451414' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267952' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10283' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:489697' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267952' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  <Record rel=<Relationship element_id='5:ae64bf75-0648-4494-b940-76395c96410e:10307' nodes=(<Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:455950' labels=frozenset() properties={}>, <Node element_id='4:ae64bf75-0648-4494-b940-76395c96410e:267966' labels=frozenset() properties={}>) type='REACTANT' properties={'__csv_type': 'REACTANT'}>>,
#  ...]

# %%
queries = ['count_root_nodes', 'count_leaf_nodes', 'average_reactant_count', 'average_product_to_molecule_ratio', 'molecules_with_multiple_products']

# Dictionary to map query names to more readable metric names
metric_names = {
    'count_root_nodes': 'Root Molecules',
    'count_leaf_nodes': 'Leaf Molecules',
    'average_reactant_count': 'Avg. Reactants per Equation',
    'average_product_to_molecule_ratio': 'Products-to-Molecules Ratio',
    'molecules_with_multiple_products': 'OR Nodes'
}

# List to store results
results = []

for query_name in queries:
    result_df = repo.execute_custom_query_from_yaml(yaml_file="./queries/table3.yaml", query_name=query_name)
    # Assuming the result is a DataFrame with a single value. Adjust if the structure is different.
    value = result_df.iloc[0, 0]
    
    # Round float values to 2 decimal places
    if isinstance(value, float):
        value = round(value, 1)
    
    results.append([metric_names[query_name], value])

# Create DataFrame
df = DataFrame(results, columns=['Metric', 'Value'])

# %%
print(df)
# Out:
#                         Metric     Value
# 0               Root Molecules  308010.0
# 1               Leaf Molecules  188614.0
# 2  Avg. Reactants per Equation       1.8
# 3  Products-to-Molecules Ratio       2.5
# 4                     OR Nodes   12347.0

# %% [markdown]
# ### Paracetamol example [Table 1]

# %%
repo = Neo4jRepository(database='uspto')

# %%
def process_target(repo, target, max_chemical_equations=None, dict_smiles_max_length=None, blacklist_smiles=None):
    if blacklist_smiles and target in blacklist_smiles:
        return 'blacklisted', target, None, None

    start_time = time.time()
    
    if dict_smiles_max_length:
        max_chemical_equations = dict_smiles_max_length.get(target, max_chemical_equations)

    node_by_smiles = repo.execute_custom_query_from_yaml(yaml_file='queries/table1.yaml', query_name='get_node_by_smiles', smiles=target)
    
    if not node_by_smiles.records:
        return 'not_found', target, None, None

    node_uid = node_by_smiles.records[0].nodes[0].uid
    try:
        if max_chemical_equations:
            dc = repo.execute_query(query_name='get_routes', root_node_uid=node_uid, max_number_reactions=max_chemical_equations)
        else:
            dc = repo.execute_query(query_name='get_routes', root_node_uid=node_uid)
        
        processing_time = time.time() - start_time
        return 'success', target, dc, processing_time
    except Exception as e:
        return 'error', target, str(e), None

# %%
dict_of_dc = {}
smiles_not_found = []
timed_out_smiles = []
error_smiles = []
targets = ['CC(=O)Nc1ccc(O)cc1']
max_number_reactions = 4
max_total_time = 300  

with ThreadPoolExecutor(max_workers=5) as executor:
    future_to_target = {executor.submit(process_target, repo, target, max_number_reactions, None, None ): target for target in targets}
    
    start_time = time.time()
    for future in as_completed(future_to_target):
        if time.time() - start_time > max_total_time:
            print("Total time exceeded. Stopping processing.")
            unprocessed_smiles = [target for target, future in future_to_target.items() if not future.done()]
            print(f"Unprocessed SMILES due to timeout: {unprocessed_smiles}")
            break

        target = future_to_target[future]
        try:
            result = future.result(timeout=20)  # 20 seconds timeout per target
            status, smiles, data, processing_time = result
            if status == 'success':
                dict_of_dc[target] =data.transform_to(format_type = 'syngraph')
                print(f'All good: {smiles}. Number of routes found: {len(data.records)}. Time taken: {processing_time:.2f} seconds.')
            elif status == 'not_found':
                smiles_not_found.append(smiles)
                #print(f'Not found: {smiles}')
            elif status == 'blacklisted':
                print(f'Skipped (blacklisted): {smiles}')
            else:
                error_smiles.append(smiles)
                print(f'Error processing {smiles}: {data}')
        except TimeoutError:
            timed_out_smiles.append(target)
            print(f'Timeout: {target}')

print(f"Processed {len(dict_of_dc.keys())} targets successfully")
print(f"Targets not found: {len(smiles_not_found)}")
print(f"Targets timed out: {len(timed_out_smiles)}")
print(f"Targets with errors: {len(error_smiles)}")
# Out:
# All good: CC(=O)Nc1ccc(O)cc1. Number of routes found: 99. Time taken: 2.67 seconds.
# Processed 1 targets successfully
# Targets not found: 0
# Targets timed out: 0
# Targets with errors: 0

# %%
# Paracetamol
investigated_smiles = 'CC(=O)Nc1ccc(O)cc1'
list_long_seq = []
list_nr_branches = []
list_nr_steps = []
for route in dict_of_dc[investigated_smiles]:
    ls = descriptor_calculator(route, "longest_seq")
    nbr = descriptor_calculator(route, "nr_branches")
    nstp = len(set(item['input_string'] for item in extract_reactions_from_syngraph(route)))
    list_long_seq.append(ls)
    list_nr_branches.append(nbr)
    list_nr_steps.append(nstp)
    
    print(f"Longest sequence: {ls}, number of branches: {nbr}, number of steps: {nstp}")
# Out:
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 6, number of steps: 7
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 3, number of branches: 4, number of steps: 5
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 2, number of branches: 2, number of steps: 3
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 0, number of branches: 3, number of steps: 5
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 0, number of branches: 2, number of steps: 3
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 0, number of branches: 4, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 0, number of branches: 3, number of steps: 4
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 6, number of steps: 7
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 0, number of branches: 2, number of steps: 3
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 0, number of branches: 2, number of steps: 3
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 6, number of steps: 7
# Longest sequence: 3, number of branches: 3, number of steps: 4
# Longest sequence: 4, number of branches: 6, number of steps: 7
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 0, number of branches: 2, number of steps: 3
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 0, number of branches: 3, number of steps: 4
# Longest sequence: 4, number of branches: 5, number of steps: 6
# Longest sequence: 4, number of branches: 5, number of steps: 6

# %%
def create_spread_string_and_average(numbers):
    if not numbers:
        return None  # Return None for an empty list

    minimum = min(numbers)
    maximum = max(numbers)
    string = f"{minimum}-{maximum}"
    average = sum(numbers)/len(numbers)

    return string, average

number_of_routes = len(dict_of_dc[investigated_smiles])
longest_seq, avg_longest_seq = create_spread_string_and_average(list_long_seq)
n_steps, avg_n_steps = create_spread_string_and_average(list_nr_steps)
n_branches, avg_n_branches = create_spread_string_and_average(list_nr_branches)

print(f"N_route: {number_of_routes}, Longest seq: {longest_seq} with average {avg_longest_seq}, N branches: {n_branches} with average {avg_n_steps}, N steps: {n_steps} with average {avg_n_branches}")
# Out:
# N_route: 99, Longest seq: 0-4 with average 3.6363636363636362, N branches: 2-6 with average 5.808080808080808, N steps: 3-7 with average 4.787878787878788

# %%
dataframe_prodCount_distinct_smiles = repo.execute_custom_query_from_yaml(yaml_file = './queries/table1.yaml', query_name='products_per_distinct_molecule', smiles = 'CC(=O)Nc1ccc(O)cc1')
prodC = dataframe_prodCount_distinct_smiles['productCount']
distinct_smiles = dataframe_prodCount_distinct_smiles['distinct_smiles']
# removed the last, because they have a single product relationship
avg_prod_count = 0
n_distinct_smiles = 0
for i in range(len(prodC[:-1].to_list())):
    avg_prod_count += int(prodC[:-1].to_list()[i])*int(distinct_smiles[:-1].to_list()[i])
    n_distinct_smiles += int(distinct_smiles[:-1].to_list()[i])
avg_prod_count = avg_prod_count/n_distinct_smiles
spread_prod_count_string = f'{min(prodC[:-1].to_list())}-{max(prodC[:-1].to_list())}'
print(f"Average number of products per OR nodes: {avg_prod_count}, min/max product per OR node: {spread_prod_count_string}, number of OR nodes: {n_distinct_smiles}")
# Out:
# Average number of products per OR nodes: 4.222222222222222, min/max product per OR node: 2-10, number of OR nodes: 9

# %%
# Create a dictionary with the data


data = {
    "Metric": [
        "Target Compound",
        "Smiles",
        "Number of Routes",
        "Longest Sequence",
        "Number of Steps",
        "Number of Branches",
        "Number of OR nodes*",
        "Number of Products per OR node*"
    ],
    "Value": [
        'Paracetamol',
        investigated_smiles,
        number_of_routes,
        longest_seq,
        n_steps,
        n_branches,
        n_distinct_smiles,
        spread_prod_count_string
        
    ],
    "Avg. Value":[
        '',
        '',
        '',
        avg_longest_seq,
        avg_n_steps,
        avg_n_branches,
        '',
        avg_prod_count
    ]
}

# Create a DataFrame
df = DataFrame(data)
print(df)
# Out:
#                             Metric               Value Avg. Value
# 0                  Target Compound         Paracetamol
# 1                           Smiles  CC(=O)Nc1ccc(O)cc1
# 2                 Number of Routes                  99
# 3                 Longest Sequence                 0-4   3.636364
# 4                  Number of Steps                 3-7   5.808081
# 5               Number of Branches                 2-6   4.787879
# 6              Number of OR nodes*                   9
# 7  Number of Products per OR node*                2-10   4.222222

# %% [markdown]
# ### Preparation for Table 2

# %%
PaRoute_PATH = '../data/paroute'
N1_ROUTES = os.path.join(PaRoute_PATH, 'n1-routes.json')
N1_TARGETS = os.path.join(PaRoute_PATH, 'n1-targets.txt')
N5_ROUTES = os.path.join(PaRoute_PATH, 'n5-routes.json')
N5_TARGETS = os.path.join(PaRoute_PATH, 'n5-targets.txt')

### Please follow the instructions in https://pubs.rsc.org/en/content/articlelanding/2022/dd/d2dd00015f PaRoutes to get the corresponding data

# %%
# Load targets

n1_targets_list = []
with open(N1_TARGETS, 'r') as file:
    for line in file:
        n1_targets_list.append(line.strip())

n5_targets_list = []
with open(N5_TARGETS, 'r') as file:
    for line in file:
        n5_targets_list.append(line.strip())

# %%
print(f"The number of n1 targets: {len(n1_targets_list)}")
print(f"The number of n5 targets: {len(n5_targets_list)}")
# Out:
# The number of n1 targets: 10000
# The number of n5 targets: 10000

# %%
def have_common_elements(list1, list2):
    set1 = set(list1)
    set2 = set(list2)
    return bool(set1 & set2)


list1 = n1_targets_list
list2 = n5_targets_list

if have_common_elements(list1, list2):
    print("The lists have common elements.")
else:
    print("The lists do not have common elements.")

# To find the common elements:
common_elements = set(list1) & set(list2)
print("Common elements:", len(common_elements))
# Out:
# The lists have common elements.
# Common elements: 2642

# %%
n1_routes = json.loads(open(N1_ROUTES).read())
n5_routes = json.loads(open(N5_ROUTES).read())

# %%
def get_shared_routes(list_of_routes, list_of_common_elements):
    result = {}
    mol_constructor = MoleculeConstructor()
    
    for route in list_of_routes:
        
        if route['smiles'] in list_of_common_elements:
            canonical_smiles = mol_constructor.build_from_molecule_string(route['smiles'], "smiles")
            if canonical_smiles.smiles not in result:
                result[canonical_smiles.smiles] = []
            result[canonical_smiles.smiles].append(route)
    
    return result

# %%
n1_and_n5_routes = n1_routes + n5_routes
routes_for_common_targets = get_shared_routes(n1_and_n5_routes, common_elements)

# %%
len(routes_for_common_targets['Cc1cccc2nc(C(C)N)c(-c3ccccn3)c(=O)n12'])
# Out:
# 2

# %%
synroutes_for_common_targets = {}

for canonical_smiles in tqdm(itertools.islice(routes_for_common_targets.keys(), 100), desc="Processing SMILES"):
    synroutes_for_common_targets[canonical_smiles] = []
    
    for az_route in routes_for_common_targets[canonical_smiles]:
        syngraph = translator('az_retro', az_route, 'syngraph', 'bipartite')
        synroutes_for_common_targets[canonical_smiles].append(syngraph)
# Out:
# Processing SMILES: 100it [00:16,  5.99it/s]

# %%
### We check that for each target all the routes in PaRoutes are the same
different_routes = []
for smiles, routes in synroutes_for_common_targets.items():
    if routes[0] != routes[1]:
        different_routes.append(smiles)

print(f'For {len(different_routes)} selected smiles the AZ routes are not the same in n1 and n5')
# Out:
# For 0 selected smiles the AZ routes are not the same in n1 and n5

# %%
# We save the longest linear sequence of AZ routes in a dictionary to mine later the routes of the same length
count = 0
dict_canonical_smiles_longest_sequence = {}
for canonical_smiles, syngraphs in synroutes_for_common_targets.items():
    syngraph0 = syngraphs[0]
    syngraph1 = syngraphs[1]
    ls = descriptor_calculator(syngraph0, "longest_seq")
    nbr = descriptor_calculator(syngraph0, "nr_branches")
    print(f"{count} smiles: {canonical_smiles}, longest sequence: {ls}, number of branches: {nbr}")
    dict_canonical_smiles_longest_sequence[canonical_smiles] = descriptor_calculator(syngraph1, "longest_seq")
    count+=1
# Out:
# 0 smiles: Cc1cccc2nc(C(C)N)c(-c3ccccn3)c(=O)n12, longest sequence: 9, number of branches: 0
# 1 smiles: CCN(C)Cc1cc2c(F)cccc2nc1CNc1ncnc(N)c1C#N, longest sequence: 9, number of branches: 0
# 2 smiles: Cc1ccc(CC(=O)O)c(O)c1, longest sequence: 6, number of branches: 0
# 3 smiles: CN(C)C(=O)c1cc(F)cc(C(C2CN(C(c3ccc(Cl)cc3)c3cccc(C#N)c3)C2)C(C)(C)F)c1, longest sequence: 7, number of branches: 0
# 4 smiles: CCC(=O)Nc1cncc(-c2cnc3c(c2)c(C=O)nn3C2CCCCO2)c1, longest sequence: 7, number of branches: 0
# 5 smiles: COc1ccc(-c2ncc(F)c(N(C)CCCOc3ccc4c(ccn4CC(=O)O)c3)n2)cc1, longest sequence: 7, number of branches: 0
# 6 smiles: CCCCCCCCCCCCCCCCNc1ccc(C(=O)CS(=O)(=O)c2ccccc2)cc1F, longest sequence: 6, number of branches: 0
# 7 smiles: CCCN(CCC)CCCCc1cc(Cl)ccc1OCCc1ccccc1, longest sequence: 10, number of branches: 0
# 8 smiles: N#Cc1cc(Cl)c(C(=O)c2c[nH]c3cnccc23)c(Cl)c1, longest sequence: 6, number of branches: 0
# 9 smiles: COc1ccc(CN2CC(C(C)(C)S(=O)(=O)c3cccc(C(F)(F)F)c3)CC2=O)cc1, longest sequence: 7, number of branches: 0
# 10 smiles: CCc1c(F)cncc1-c1cc(Cl)c2c(c1)CCc1nnc(C)n1-2, longest sequence: 5, number of branches: 0
# 11 smiles: CN(CCCn1c(=O)[nH]c2cc(CNC[C@H](O[Si](C)(C)C(C)(C)C)c3ccc(O)c4[nH]c(=O)ccc34)ccc21)[C@H]1CC[C@H](OC(=O)C(O)(c2cccs2)c2cccs2)CC1, longest sequence: 7, number of branches: 0
# 12 smiles: CNC(=O)c1c(-c2ccc(F)cc2)oc2cc(N(C)S(C)(=O)=O)c3c(c12)CC(CN1CCOCC1)O3, longest sequence: 7, number of branches: 0
# 13 smiles: CCC(O)(/C=C/c1ccc(C(CC)(CC)c2cc(C)c(-c3ccc(CC(=O)O)c(F)c3)c(C)c2)cc1C)CC, longest sequence: 6, number of branches: 2
# 14 smiles: CCc1c(NC(=S)NCCN)ccc2ocnc12, longest sequence: 8, number of branches: 0
# 15 smiles: O=C1c2ccccc2C(=O)N1CCn1c(=O)n(C2CCN(C3CC4CCCc5cccc3c54)CC2)c2ccccc21, longest sequence: 6, number of branches: 0
# 16 smiles: Clc1ncnc2cc(OCCCN3CCOCC3)ccc12, longest sequence: 7, number of branches: 0
# 17 smiles: COc1ccc2nccc(N3CCC(N(CCN)C(=O)OC(C)(C)C)C3)c2n1, longest sequence: 6, number of branches: 0
# 18 smiles: CC(C)(C)OC(=O)n1c(-c2cnc(Nc3cccc(NS(C)(=O)=O)c3)o2)cc2cc(F)ccc21, longest sequence: 6, number of branches: 0
# 19 smiles: Cc1cc2c(Cc3ccc(OCCN4CCCC4)cc3)c(-c3ccc(C(F)(F)F)cc3)c(=O)oc2cc1O, longest sequence: 6, number of branches: 0
# 20 smiles: CCOC(=O)c1cc2c(C(F)(F)F)ccc(OCC#N)c2n1C, longest sequence: 7, number of branches: 0
# 21 smiles: COc1ccc(-n2nc(C(N)=O)c3c2C(=O)N(c2ccc(N(C#N)CCO[Si](C)(C)C(C)(C)C)cc2)CC3)cc1, longest sequence: 6, number of branches: 0
# 22 smiles: CC(C)(C)NCC(O)c1cc(F)cc(C#N)c1F, longest sequence: 7, number of branches: 0
# 23 smiles: CCC(CC)(c1ccc(CN(CCS(C)(=O)=O)C(=O)OC(C)(C)C)c(C)c1)c1ccc(OCC(O)C(C)(C)C)c(C)c1, longest sequence: 6, number of branches: 0
# 24 smiles: C/C(=C\CO)c1ccc2c(c1)CCCN2C(C)C, longest sequence: 6, number of branches: 0
# 25 smiles: O=C1Cc2ccccc2Oc2cc(F)ccc21, longest sequence: 7, number of branches: 0
# 26 smiles: CC(C)(C)C(=O)C(=O)C(C)(C)C, longest sequence: 3, number of branches: 0
# 27 smiles: COc1cc(C(F)(F)F)ccc1C(=O)c1cccn1-c1ccn(S(=O)(=O)c2ccc(C)cc2)c1C(=O)c1ccc(C(F)(F)F)cc1OC, longest sequence: 7, number of branches: 0
# 28 smiles: CCCCCCCCCCCCCCCCSCC(CBr)OCC, longest sequence: 7, number of branches: 0
# 29 smiles: C#Cc1cc2cn[nH]c2c(C(=O)NC2(C3CC3)CC2)c1NC(=O)c1cc(C(F)(F)F)nn1-c1ncccc1Cl, longest sequence: 6, number of branches: 0
# 30 smiles: Cc1ccc(Nc2cccc3c4c(n(C)c23)CCN(C)C4)cc1, longest sequence: 6, number of branches: 0
# 31 smiles: CCn1cc(N2CCN(C(=O)OC)CC2=O)c2ccc(OCc3ccccn3)nc21, longest sequence: 6, number of branches: 0
# 32 smiles: COc1cc2c(cc1Nc1nc3ccc(-c4ccc(NC(=O)[C@H](C)c5ccc(F)cc5)cc4)cn3n1)CCS2(=O)=O, longest sequence: 6, number of branches: 0
# 33 smiles: CCOC(=O)c1ccc(-n2cc(C#N)c(-c3ccccc3OCCOC)c2)cc1OCOC, longest sequence: 5, number of branches: 0
# 34 smiles: COc1cc(C(C)(C)C)c(OC(C)=O)c(C(C)(C)C)c1CC=O, longest sequence: 6, number of branches: 0
# 35 smiles: COc1cc2nc(-c3cccc([N+](=O)[O-])c3)nc(Nc3ccc4c(cnn4C(=O)OC(C)(C)C)c3)c2cc1OCCCN1CCOCC1, longest sequence: 6, number of branches: 0
# 36 smiles: COc1cccc(Sc2cnc(Nc3nc(C4CCN(C(=O)OC(C)(C)C)CC4)cs3)cc2Oc2cccnc2C)c1, longest sequence: 8, number of branches: 0
# 37 smiles: O=C(N[C@@H]1CCCC[C@H]1O)c1nc(-c2ccc(Cl)cc2)c(OCC2CC2)nc1C(F)(F)F, longest sequence: 6, number of branches: 0
# 38 smiles: OCCC(Cn1ccnc1)c1ccc(Cl)c(Cl)c1, longest sequence: 6, number of branches: 0
# 39 smiles: CCOP(=O)(CCC(CO[Si](C)(C)C(C)(C)C)On1cnc2c(N)ncnc21)OCC, longest sequence: 7, number of branches: 0
# 40 smiles: O=C(NO)[C@@H](CCCN1C(=O)c2ccccc2C1=O)NS(=O)(=O)c1ccc(-c2ccc(Cl)cc2)cc1, longest sequence: 6, number of branches: 0
# 41 smiles: CCn1c(=O)c2c(C)[nH]nc2c2cc(-c3ccc(CN4CCCC4)s3)ccc21, longest sequence: 6, number of branches: 0
# 42 smiles: CC(C(=O)OCc1ccccc1)c1ccc(-c2ccc(NC(=O)COc3ccc(C(=O)c4ccc(OCC(=O)NCCN)cc4)cc3)cc2)c(F)c1, longest sequence: 6, number of branches: 0
# 43 smiles: COc1nc(-c2c(C)ccc3[nH]ncc23)nc2c1CN(c1cc(C(C)C)ccc1C)CC2, longest sequence: 6, number of branches: 0
# 44 smiles: CCCCC[C@H](CC(=O)NCc1c(C(C)C)cccc1C(C)C)c1cccc2c1OCO2, longest sequence: 7, number of branches: 0
# 45 smiles: CC1CN(c2ccc3nc(N)c(C#N)c(NCc4ccccc4)c3c2)CC(C)O1, longest sequence: 6, number of branches: 0
# 46 smiles: CCc1nc(N)nc(N[C@@H](C)c2nc3ccn(C)c3cc2N2CCN(C(=O)OC(C)(C)C)CC2)c1C#N, longest sequence: 4, number of branches: 2
# 47 smiles: O=C(NC(Cc1ccc2nc(-c3c(Cl)cccc3Cl)ccc2c1)c1nnn[nH]1)c1c(Cl)cccc1Cl, longest sequence: 6, number of branches: 0
# 48 smiles: COc1c(C(=O)OC2=CC(=O)CCC2)ccc(C(F)(F)F)c1SC, longest sequence: 6, number of branches: 0
# 49 smiles: O=C(O)c1nc(-c2ccc(C(F)(F)F)cc2)oc1-c1ccc(-c2cccnc2)cc1, longest sequence: 5, number of branches: 0
# 50 smiles: Cc1c(C(=O)Nc2ccc(Oc3ccnc4cc(OCCO)ccc34)cc2)c(=O)n(-c2ccccc2)n1C, longest sequence: 6, number of branches: 0
# 51 smiles: CNC(=O)COc1cccc(CN2C(=O)C3(COc4cc5c(cc43)CCO5)c3ccccc32)c1, longest sequence: 6, number of branches: 0
# 52 smiles: CC(C)(CN1CCOCC1)n1c(=O)[nH]c2cc(Br)ccc21, longest sequence: 5, number of branches: 0
# 53 smiles: O=C(O)COCCOCCOCCOCCOCCOCCOCC(F)(F)F, longest sequence: 6, number of branches: 0
# 54 smiles: CC(C)Oc1ccc2c(c1Cc1ccc(F)cc1)c(=O)n(CCCO)c(=O)n2C, longest sequence: 5, number of branches: 0
# 55 smiles: CCC1(C)CC2(C(=O)N(C)C(=O)N2C)C(C)C(C)(CC)N1C, longest sequence: 4, number of branches: 0
# 56 smiles: FC(F)c1ccc(C(F)(F)CN2CCC(Nc3ncnc4[nH]ccc34)CC2)cc1, longest sequence: 6, number of branches: 0
# 57 smiles: CCCCCC#Cc1ccccc1, longest sequence: 5, number of branches: 0
# 58 smiles: Cc1cn(-c2cc(C)c(N)c(C=O)c2)cn1, longest sequence: 5, number of branches: 0
# 59 smiles: CNc1ccc(-c2nn(C(C)C)cc2-c2ccnc(NC[C@H](C)O)n2)cn1, longest sequence: 4, number of branches: 2
# 60 smiles: COc1cc(OS(C)(=O)=O)ccc1-c1ccc2c(c1COc1cc(F)ccc1C)N(C)C(=O)C(C)(C)N2, longest sequence: 6, number of branches: 0
# 61 smiles: CN1CCNC(CCOc2ccccc2)C1, longest sequence: 6, number of branches: 0
# 62 smiles: CC1(COc2ccc(CC3SC(=O)NC3=O)cc2)CC(=O)c2cc(O)c(C(C)(C)C)cc2O1, longest sequence: 4, number of branches: 0
# 63 smiles: COc1ccc(Cn2cc(C(=O)N(C)C3CCN(c4nnc(-c5ccc(F)cc5)c(C)c4C)CC3)c(C(F)(F)F)n2)cc1, longest sequence: 4, number of branches: 2
# 64 smiles: C=Cc1ccc(N(c2ccccc2)c2ccc(-c3ccc(C#N)c(C#N)c3)cc2)cc1, longest sequence: 4, number of branches: 0
# 65 smiles: CC1(CCS)C(=O)N2CC=CC(C(=O)O)N2C1=O, longest sequence: 6, number of branches: 0
# 66 smiles: OCC1(c2ncccn2)CCC(NC2CC2)CC1, longest sequence: 7, number of branches: 0
# 67 smiles: C[C@@H](Nc1cc(B2OC(C)(C)C(C)(C)O2)ccc1Cl)c1ccc(Cl)cc1Cl, longest sequence: 5, number of branches: 0
# 68 smiles: CC1=C(C#N)[C@@H](c2ccc(C#N)cc2S(=O)(=O)Cl)N(C)C(=O)N1c1cccc(C(F)(F)F)c1, longest sequence: 5, number of branches: 0
# 69 smiles: CC[Si](CC)(CC)OC(CNCC(C)(C)C)c1c(Cl)cnc2ccccc12, longest sequence: 5, number of branches: 0
# 70 smiles: CC(C)(C)OC(=O)Nc1ccc(-c2cnc(N3CCOCC3)c3nc(COc4ccc5ccccc5n4)cn23)cn1, longest sequence: 6, number of branches: 0
# 71 smiles: CC(C(N)=O)c1ccc(C(=O)c2cccs2)cc1, longest sequence: 6, number of branches: 0
# 72 smiles: CCCCc1nc2c[n+]([O-])c3ccccc3c2n1CCCCCC(=O)c1ccccc1, longest sequence: 6, number of branches: 0
# 73 smiles: Cc1nc(-c2ccc(CNC(=O)OC(C)(C)C)c(N)c2)no1, longest sequence: 6, number of branches: 0
# 74 smiles: CC(C)c1c(C(=O)NCc2ccc(F)c(F)c2)c2cc(O)ncc2n1Cc1ccccc1, longest sequence: 5, number of branches: 0
# 75 smiles: CN(c1c(Cl)ccc2cc(-c3ncc(CO)s3)[nH]c12)S(=O)(=O)c1cccs1, longest sequence: 6, number of branches: 0
# 76 smiles: N#Cc1cc(-c2ccc(O)cc2)cc2ccc(O)c(Br)c12, longest sequence: 6, number of branches: 0
# 77 smiles: COCc1c(C(N)=NO)ncc2[nH]c3cccc(Oc4ccccc4)c3c12, longest sequence: 6, number of branches: 0
# 78 smiles: Nc1ccccc1CN1CCOCC1=O, longest sequence: 4, number of branches: 0
# 79 smiles: CC1(C)CC=C(c2cc(C3(C#N)CCCCC3)ccc2NC(=O)c2nc(C#N)c[nH]2)CC1, longest sequence: 5, number of branches: 0
# 80 smiles: O=c1c2c[nH]c3ccc(N4CCNCC4)cc3c-2nn1-c1ccc(Cl)cc1, longest sequence: 5, number of branches: 0
# 81 smiles: Cc1ccc(-n2ccc(NC(=O)c3cc(Cl)ccc3NC(=O)c3cccc(CSCCC(=O)O)c3)n2)cc1C, longest sequence: 6, number of branches: 0
# 82 smiles: CCc1nc(NC2CCCC2)c(-c2ccccc2)c(NC2CCCC2)n1, longest sequence: 5, number of branches: 0
# 83 smiles: Oc1ccc(-c2nn3ccc(NC4CCCC4)cc3c2-c2ccnc(NC3CCCC3)n2)cc1, longest sequence: 7, number of branches: 0
# 84 smiles: CS(=O)(=O)N1CCN(c2ccc(C3CC4CCC(C3)N4)cc2)CC1, longest sequence: 5, number of branches: 0
# 85 smiles: O=C(CCc1c[nH]c2cnc(-n3cncn3)cc12)NN1CCN(Cc2ccccc2)CC1, longest sequence: 6, number of branches: 0
# 86 smiles: CN(C)C(=O)C1CCN(c2cccc(-c3ccc4nc(-c5cccnc5N)n(-c5ccc(C6(NC(=O)OC(C)(C)C)CCC6)cc5)c4n3)c2)CC1, longest sequence: 5, number of branches: 0
# 87 smiles: CNC(=O)CC(C(=O)N(C)[C@H](C)C(=O)O)c1ccc(OCc2cc(C(F)(F)F)cc(C(F)(F)F)c2)cc1, longest sequence: 7, number of branches: 0
# 88 smiles: CCOC(=O)C(C)(C)Oc1cc(C)c(Cc2ccc(OCc3ccccc3)c(S(=O)(=O)c3ccc(F)cc3)c2)c(C)c1, longest sequence: 6, number of branches: 2
# 89 smiles: CCCN(C1CCN(C(=O)N2CCOCC2)CC1)C1CCc2ccc(OS(=O)(=O)c3ccccc3Cl)cc2C1, longest sequence: 6, number of branches: 0
# 90 smiles: CCOC(=O)c1cn(C2CCCCC2)c2cc(I)ccc2c1=O, longest sequence: 6, number of branches: 0
# 91 smiles: COCOC(C)c1ccc(CCOc2ccc(CC3SC(=O)NC3=O)cc2)nc1, longest sequence: 6, number of branches: 0
# 92 smiles: COc1cc(OC)cc(-c2c(-c3ccccc3F)cnc(C)c2-c2c(F)cc(F)cc2F)c1, longest sequence: 6, number of branches: 0
# 93 smiles: Cc1cc(N(C)C)nc2ccc(C=O)cc12, longest sequence: 5, number of branches: 0
# 94 smiles: COCCOc1cc(Oc2ccccc2)cnc1Nc1nccs1, longest sequence: 5, number of branches: 0
# 95 smiles: CCNC1(CO)CCN(C)CC1, longest sequence: 4, number of branches: 0
# 96 smiles: Cc1cccc(-c2ccc(CN3CCN(C(=O)OC(C(F)(F)F)C(F)(F)F)CC3)c(Oc3ccccc3)c2)c1, longest sequence: 5, number of branches: 0
# 97 smiles: Cc1ccc2cc(CN)ccc2n1, longest sequence: 5, number of branches: 0
# 98 smiles: CS(=O)(=O)Nc1ccc(OCC2CCN(c3cc(N)ccn3)CC2)cc1, longest sequence: 6, number of branches: 0
# 99 smiles: CC(C)C[C@@H](C(=O)NN(CC(C)C)C(=O)Cn1ccnc1)[C@H](CCNC(=O)c1ccccc1)C(=O)O, longest sequence: 5, number of branches: 0

# %% [markdown]
# ### Comparison to PaRoute dataset [Table 2]

# %% [markdown]
# Because some of the targets are not present in MIT UPSTO, we add the routes for some selected targets to USPTO dataset
# for the sake of comparing the routes mined with Noctis.
# We chose to select among the targets which are shared among n1 set and n5 set.
# We investigated first 10 targets and we took one target with branching route.

# %%
### adding first 10 targets shared between n1 and n5
repo.execute_query(query_name = 'load_nodes_and_relationships', data = [synroutes_for_common_targets[smls][0] for smls in  itertools.islice(routes_for_common_targets.keys(), 10)], data_type = 'syngraph', output_chem_format = 'smiles')
# Out:
# []

# %%
### adding a target with branching route
repo.execute_query(query_name = 'load_nodes_and_relationships', data = [synroutes_for_common_targets[smls][0] for smls in ['CCC(O)(/C=C/c1ccc(C(CC)(CC)c2cc(C)c(-c3ccc(CC(=O)O)c(F)c3)c(C)c2)cc1C)CC']], data_type = 'syngraph', output_chem_format = 'smiles')
# Out:
# []

# %%
dict_of_dc = {}
smiles_not_found = []
timed_out_smiles = []
error_smiles = []
# These are smiles for which route mining explodes due to large number of mined routes
blacklisted_smiles = ['CCC(=O)Nc1cncc(-c2cnc3c(c2)c(C=O)nn3C2CCCCO2)c1', 'CCCCCCCCCCCCCCCCNc1ccc(C(=O)CS(=O)(=O)c2ccccc2)cc1F', 'CCCN(CCC)CCCCc1cc(Cl)ccc1OCCc1ccccc1', 'Cc1cccc2nc(C(C)N)c(-c3ccccn3)c(=O)n12', 'CCN(C)Cc1cc2c(F)cccc2nc1CNc1ncnc(N)c1C#N']
targets = list(itertools.islice(routes_for_common_targets.keys(), 10) )
targets.append('CCC(O)(/C=C/c1ccc(C(CC)(CC)c2cc(C)c(-c3ccc(CC(=O)O)c(F)c3)c(C)c2)cc1C)CC')
max_total_time = 300  # 5 minutes total timeout


with ThreadPoolExecutor(max_workers=5) as executor:
    future_to_target = {executor.submit(process_target, repo, target,None, dict_canonical_smiles_longest_sequence, blacklisted_smiles): target for target in targets}
    
    start_time = time.time()
    for future in as_completed(future_to_target):
        if time.time() - start_time > max_total_time:
            print("Total time exceeded. Stopping processing.")
            unprocessed_smiles = [target for target, future in future_to_target.items() if not future.done()]
            print(f"Unprocessed SMILES due to timeout: {unprocessed_smiles}")
            break

        target = future_to_target[future]
        try:
            result = future.result(timeout=20)  # 20 seconds timeout per target
            status, smiles, data, processing_time = result
            if status == 'success':
                dict_of_dc[target] =data.transform_to(format_type = 'syngraph')
                print(f'All good: {smiles}. Number of routes found: {len(data.records)}. Time taken: {processing_time:.2f} seconds. Length in PaRoutes: {dict_canonical_smiles_longest_sequence[smiles]}')
            elif status == 'not_found':
                smiles_not_found.append(smiles)
                #print(f'Not found: {smiles}')
            elif status == 'blacklisted':
                print(f'Skipped (blacklisted): {smiles}')
            else:
                error_smiles.append(smiles)
                print(f'Error processing {smiles}: {data}')
        except TimeoutError:
            timed_out_smiles.append(target)
            print(f'Timeout: {target}')

print(f"Processed {len(dict_of_dc.keys())} targets successfully")
print(f"Targets not found: {len(smiles_not_found)}")
print(f"Targets timed out: {len(timed_out_smiles)}")
print(f"Targets with errors: {len(error_smiles)}")
print(f"Targets blacklisted: {len(blacklisted_smiles)}")
# Out:
# Skipped (blacklisted): CCCN(CCC)CCCCc1cc(Cl)ccc1OCCc1ccccc1
# Skipped (blacklisted): CCC(=O)Nc1cncc(-c2cnc3c(c2)c(C=O)nn3C2CCCCO2)c1
# Skipped (blacklisted): CCN(C)Cc1cc2c(F)cccc2nc1CNc1ncnc(N)c1C#N
# Skipped (blacklisted): CCCCCCCCCCCCCCCCNc1ccc(C(=O)CS(=O)(=O)c2ccccc2)cc1F
# Skipped (blacklisted): Cc1cccc2nc(C(C)N)c(-c3ccccn3)c(=O)n12
# All good: Cc1ccc(CC(=O)O)c(O)c1. Number of routes found: 6. Time taken: 1.10 seconds. Length in PaRoutes: 6
# All good: CCC(O)(/C=C/c1ccc(C(CC)(CC)c2cc(C)c(-c3ccc(CC(=O)O)c(F)c3)c(C)c2)cc1C)CC. Number of routes found: 270. Time taken: 1.85 seconds. Length in PaRoutes: 6
# All good: COc1ccc(-c2ncc(F)c(N(C)CCCOc3ccc4c(ccn4CC(=O)O)c3)n2)cc1. Number of routes found: 3. Time taken: 3.22 seconds. Length in PaRoutes: 7
# All good: N#Cc1cc(Cl)c(C(=O)c2c[nH]c3cnccc23)c(Cl)c1. Number of routes found: 3. Time taken: 3.40 seconds. Length in PaRoutes: 6
# All good: CN(C)C(=O)c1cc(F)cc(C(C2CN(C(c3ccc(Cl)cc3)c3cccc(C#N)c3)C2)C(C)(C)F)c1. Number of routes found: 11. Time taken: 3.58 seconds. Length in PaRoutes: 7
# All good: COc1ccc(CN2CC(C(C)(C)S(=O)(=O)c3cccc(C(F)(F)F)c3)CC2=O)cc1. Number of routes found: 1. Time taken: 3.57 seconds. Length in PaRoutes: 7
# Processed 6 targets successfully
# Targets not found: 0
# Targets timed out: 0
# Targets with errors: 0
# Targets blacklisted: 5

# %%
# a function to check if AZ routes is a subset to Boctis routes
def find_shared_reactions_between_two_syngraphs(obj1, obj2):
    input_strings1 = set(item['input_string'] for item in extract_reactions_from_syngraph(obj1))
    input_strings2 = set(item['input_string'] for item in extract_reactions_from_syngraph(obj2))

    # Find similar input_strings
    similar_strings = input_strings1.intersection(input_strings2)

    # Count of similar strings
    count_similar = len(similar_strings)

    return similar_strings, count_similar, len(input_strings1), len(input_strings2)

# %%
exact_match = {}
shared_reactions = {}
steps_az = {}
steps_ncts = {}
long_seq_az = {}
long_seq_ncts = {}
branch_az = {}
branch_ncts = {}
routes_which_donot_contain_some_reactions= {}
for smiles, noctis_syngraphs in dict_of_dc.items():
    exact_match[smiles] = []
    shared_reactions[smiles] = []
    steps_az[smiles] = []
    steps_ncts[smiles] = []
    long_seq_az[smiles] = []
    long_seq_ncts[smiles] = []
    branch_az[smiles] = []
    branch_ncts[smiles] = []
    routes_which_donot_contain_some_reactions[smiles] = []
    print(f"{smiles}, N route mined with Noctis: {len(noctis_syngraphs)} ----------------------")
    for i, ncts_sng in enumerate(noctis_syngraphs):
        
        az_sng = synroutes_for_common_targets[smiles][0]
        print(f"{i} Exact match Noctis and AZ routes: {ncts_sng == az_sng}")
        exact_match[smiles].append(ncts_sng == az_sng)
        r, nr_shared, stp_az, stp_ncts = find_shared_reactions_between_two_syngraphs(az_sng,ncts_sng)
        az_ls = descriptor_calculator(az_sng, "longest_seq")
        ncts_ls = descriptor_calculator(ncts_sng, "longest_seq")
        az_nrb = descriptor_calculator(az_sng, "nr_branches")
        ncts_nrb = descriptor_calculator(ncts_sng, "nr_branches")
        shared_reactions[smiles].append(nr_shared)
        steps_az[smiles] = [stp_az]
        steps_ncts[smiles].append(stp_ncts)
        long_seq_az[smiles] = [az_ls]
        long_seq_ncts[smiles] = [ncts_ls]
        branch_az[smiles] = [az_nrb]
        branch_ncts[smiles] = [ncts_nrb]
        print(f"N reactions shared: {nr_shared}, N steps in AZ route: {stp_az}, in Noctis route: {stp_ncts}")
        if nr_shared != stp_az:
            routes_which_donot_contain_some_reactions[smiles].append(i)
        print(f"Longest sequence in AZ route: {az_ls}, in Noctis route: {ncts_ls}")
        print(f"N branches in AZ route: {az_nrb}, in Noctis route: {ncts_nrb}")
    print("")

    print(f"Routes which do not contain some reactions from AZ route: {len(routes_which_donot_contain_some_reactions[smiles])}")
# Out:
# Cc1ccc(CC(=O)O)c(O)c1, N route mined with Noctis: 6 ----------------------
# 0 Exact match Noctis and AZ routes: False
# N reactions shared: 6, N steps in AZ route: 6, in Noctis route: 7
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 0, in Noctis route: 2
# 1 Exact match Noctis and AZ routes: False
# N reactions shared: 5, N steps in AZ route: 6, in Noctis route: 8
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 0, in Noctis route: 3
# 2 Exact match Noctis and AZ routes: False
# N reactions shared: 6, N steps in AZ route: 6, in Noctis route: 7
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 0, in Noctis route: 2
# 3 Exact match Noctis and AZ routes: False
# N reactions shared: 5, N steps in AZ route: 6, in Noctis route: 7
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 0, in Noctis route: 2
# 4 Exact match Noctis and AZ routes: False
# N reactions shared: 5, N steps in AZ route: 6, in Noctis route: 7
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 0, in Noctis route: 2
# 5 Exact match Noctis and AZ routes: False
# N reactions shared: 6, N steps in AZ route: 6, in Noctis route: 8
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 0, in Noctis route: 3
#
# Routes which do not contain some reactions from AZ route: 3
# CCC(O)(/C=C/c1ccc(C(CC)(CC)c2cc(C)c(-c3ccc(CC(=O)O)c(F)c3)c(C)c2)cc1C)CC, N route mined with Noctis: 270 ----------------------
# 0 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 1 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 2 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 3 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 4 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 5 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 6 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 7 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 8 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 9 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 10 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 11 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 12 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 13 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 14 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 15 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 16 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 17 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 18 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 19 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 20 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 21 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 22 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 23 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 24 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 25 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 26 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 27 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 28 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 29 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 30 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 31 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 32 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 33 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 34 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 35 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 36 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 37 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 38 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 39 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 40 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 41 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 42 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 43 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 44 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 45 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 46 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 47 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 48 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 49 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 50 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 51 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 52 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 53 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 54 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 55 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 56 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 57 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 58 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 59 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 60 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 61 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 62 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 63 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 64 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 65 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 66 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 67 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 68 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 69 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 70 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 71 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 72 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 73 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 74 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 75 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 76 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 77 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 78 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 79 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 80 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 81 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 82 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 83 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 84 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 85 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 86 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 87 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 88 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 89 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 90 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 91 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 92 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 93 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 94 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 95 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 96 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 97 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 98 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 99 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 100 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 101 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 102 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 103 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 104 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 105 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 106 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 107 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 108 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 109 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 110 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 111 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 112 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 113 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 114 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 115 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 116 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 117 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 118 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 119 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 120 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 121 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 122 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 123 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 124 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 125 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 126 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 127 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 128 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 129 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 130 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 131 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 132 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 133 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 134 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 135 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 136 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 137 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 138 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 139 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 140 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 141 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 142 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 143 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 144 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 145 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 146 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 147 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 148 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 149 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 150 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 151 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 152 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 153 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 154 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 155 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 156 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 157 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 158 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 159 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 160 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 161 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 162 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 163 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 164 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 165 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 166 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 167 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 168 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 169 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 170 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 171 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 172 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 173 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 174 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 175 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 176 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 177 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 178 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 179 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 180 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 181 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 182 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 183 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 184 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 185 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 186 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 187 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 188 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 189 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 190 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 191 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 192 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 193 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 194 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 195 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 196 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 197 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 198 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 199 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 200 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 201 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 202 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 203 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 204 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 205 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 206 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 207 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 208 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 209 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 210 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 211 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 212 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 213 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 214 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 215 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 216 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 217 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 218 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 219 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 220 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 221 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 222 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 223 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 224 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 225 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 226 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 227 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 228 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 229 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 230 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 231 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 232 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 233 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 234 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 235 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 236 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 237 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 238 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 239 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 240 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 241 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 242 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 243 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 244 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 245 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 246 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 247 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 248 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 249 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 250 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 251 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 252 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 253 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 254 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 255 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 256 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 257 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 258 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 259 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 260 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 261 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 262 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 263 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 264 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 265 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 266 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 12
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 267 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 13
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 6
# 268 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
# 269 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 2, in Noctis route: 4
#
# Routes which do not contain some reactions from AZ route: 0
# COc1ccc(-c2ncc(F)c(N(C)CCCOc3ccc4c(ccn4CC(=O)O)c3)n2)cc1, N route mined with Noctis: 3 ----------------------
# 0 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 6
# 1 Exact match Noctis and AZ routes: False
# N reactions shared: 0, N steps in AZ route: 7, in Noctis route: 1
# Longest sequence in AZ route: 7, in Noctis route: 1
# N branches in AZ route: 0, in Noctis route: 0
# 2 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 11
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 6
#
# Routes which do not contain some reactions from AZ route: 1
# N#Cc1cc(Cl)c(C(=O)c2c[nH]c3cnccc23)c(Cl)c1, N route mined with Noctis: 3 ----------------------
# 0 Exact match Noctis and AZ routes: False
# N reactions shared: 6, N steps in AZ route: 6, in Noctis route: 8
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 0, in Noctis route: 4
# 1 Exact match Noctis and AZ routes: False
# N reactions shared: 6, N steps in AZ route: 6, in Noctis route: 8
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 0, in Noctis route: 4
# 2 Exact match Noctis and AZ routes: False
# N reactions shared: 6, N steps in AZ route: 6, in Noctis route: 9
# Longest sequence in AZ route: 6, in Noctis route: 6
# N branches in AZ route: 0, in Noctis route: 5
#
# Routes which do not contain some reactions from AZ route: 0
# CN(C)C(=O)c1cc(F)cc(C(C2CN(C(c3ccc(Cl)cc3)c3cccc(C#N)c3)C2)C(C)(C)F)c1, N route mined with Noctis: 11 ----------------------
# 0 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 9
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 4
# 1 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 5
# 2 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 5
# 3 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 9
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 4
# 4 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 9
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 4
# 5 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 5
# 6 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 9
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 4
# 7 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 9
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 4
# 8 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 5
# 9 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 5
# 10 Exact match Noctis and AZ routes: False
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 10
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 5
#
# Routes which do not contain some reactions from AZ route: 0
# COc1ccc(CN2CC(C(C)(C)S(=O)(=O)c3cccc(C(F)(F)F)c3)CC2=O)cc1, N route mined with Noctis: 1 ----------------------
# 0 Exact match Noctis and AZ routes: True
# N reactions shared: 7, N steps in AZ route: 7, in Noctis route: 7
# Longest sequence in AZ route: 7, in Noctis route: 7
# N branches in AZ route: 0, in Noctis route: 0
#
# Routes which do not contain some reactions from AZ route: 0

# %%
def create_separator(widths):
    return '+' + '+'.join('-' * (w + 2) for w in widths) + '+'

def create_row(data, widths):
    return '| ' + ' | '.join(f"{d:<{w}}" for d, w in zip(data, widths)) + ' |'

# Define headers
headers = headers = [
    "SMILES",
    "N Routes",
    "Shared Reactions",
    "Steps AZ/Noctis",
    "LongSeq AZ/Noctis",
    "Branches AZ/Noctis",
    "AZ Route recovered",
    "Not AZ Superset"
]

# Prepare the data
table_data = []
for smiles in dict_of_dc.keys():
    if min(shared_reactions[smiles]) == max(shared_reactions[smiles]):
        min_max = str(min(shared_reactions[smiles]))
    else:
        min_max = f'{min(shared_reactions[smiles])}-{max(shared_reactions[smiles])}'
     
    if min(steps_ncts[smiles]) == max(steps_ncts[smiles]):
        stp_az_ncts = f"{str(steps_az[smiles][0])}/{str(min(steps_ncts[smiles]))}"
    else:
        stp_az_ncts = f'{str(steps_az[smiles][0])}/{min(steps_ncts[smiles])}-{max(steps_ncts[smiles])}'
        
    if min(long_seq_ncts[smiles]) == max(long_seq_ncts[smiles]):
        ls_az_ncts = f"{long_seq_az[smiles][0]}/{min(long_seq_ncts[smiles])}"
    else:
        ls_az_ncts = f'{long_seq_az[smiles][0]}/{min(long_seq_ncts[smiles])}-{max(long_seq_ncts[smiles])}'
        
    if min(branch_ncts[smiles]) == max(branch_ncts[smiles]):
        br_az_ncts = f"{branch_az[smiles][0]}/{min(branch_ncts[smiles])}"
    else:
        br_az_ncts = f'{branch_az[smiles][0]}/{min(branch_ncts[smiles])}-{max(branch_ncts[smiles])}'
    
    if len(routes_which_donot_contain_some_reactions[smiles])< max(shared_reactions[smiles]):
        az_recovered = 'Yes'
    else:
        az_recovered = 'No'
    
    row = [
        smiles,
        str(len(dict_of_dc[smiles])),
        min_max,
        stp_az_ncts,
        ls_az_ncts,
        br_az_ncts,
        az_recovered,
        f'{str(len(routes_which_donot_contain_some_reactions[smiles]))}/{str(len(dict_of_dc[smiles]))}'
    ]
    table_data.append(row)

# Calculate column widths
widths = [max(len(str(row[i])) for row in table_data + [headers]) for i in range(len(headers))]

# Print the table
print(create_separator(widths))
print(create_row(headers, widths))
print(create_separator(widths))
for row in table_data:
    print(create_row(row, widths))
print(create_separator(widths))
# Out:
# +--------------------------------------------------------------------------+----------+------------------+-----------------+-------------------+--------------------+--------------------+-----------------+
# | SMILES                                                                   | N Routes | Shared Reactions | Steps AZ/Noctis | LongSeq AZ/Noctis | Branches AZ/Noctis | AZ Route recovered | Not AZ Superset |
# +--------------------------------------------------------------------------+----------+------------------+-----------------+-------------------+--------------------+--------------------+-----------------+
# | Cc1ccc(CC(=O)O)c(O)c1                                                    | 6        | 5-6              | 6/7-8           | 6/6               | 0/3                | True               | 3/6             |
# | CCC(O)(/C=C/c1ccc(C(CC)(CC)c2cc(C)c(-c3ccc(CC(=O)O)c(F)c3)c(C)c2)cc1C)CC | 270      | 7                | 7/10-13         | 6/6               | 2/4                | True               | 0/270           |
# | COc1ccc(-c2ncc(F)c(N(C)CCCOc3ccc4c(ccn4CC(=O)O)c3)n2)cc1                 | 3        | 0-7              | 7/1-11          | 7/7               | 0/6                | True               | 1/3             |
# | N#Cc1cc(Cl)c(C(=O)c2c[nH]c3cnccc23)c(Cl)c1                               | 3        | 6                | 6/8-9           | 6/6               | 0/5                | True               | 0/3             |
# | CN(C)C(=O)c1cc(F)cc(C(C2CN(C(c3ccc(Cl)cc3)c3cccc(C#N)c3)C2)C(C)(C)F)c1   | 11       | 7                | 7/9-10          | 7/7               | 0/5                | True               | 0/11            |
# | COc1ccc(CN2CC(C(C)(C)S(=O)(=O)c3cccc(C(F)(F)F)c3)CC2=O)cc1               | 1        | 7                | 7/7             | 7/7               | 0/0                | True               | 0/1             |
# +--------------------------------------------------------------------------+----------+------------------+-----------------+-------------------+--------------------+--------------------+-----------------+
